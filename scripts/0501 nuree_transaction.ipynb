# %%
import pandas as pd
import numpy as np

import os

# %%
# setup credentials
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = (
    os.path.abspath("../credentials/github.txt"))

# %load_ext google.cloud.bigquery

# %% [markdown]
# ### Notes

# %% [markdown]
# [Reference](https://arxiv.org/pdf/1911.00169.pdf)

# %% [markdown]
# - 위 논문에서는 데이터를 block, trace, receipt로 구분
# - bigquery에서는 어떻게 매칭되는지 잘 모르겟음
# - trace는 그 trace가 맞는 거 같음

# %% [markdown]
# **Trace**
# - Trace data cannot be directly obtained or observed from the contract execution
#   - only appears during the execution
# - Trace Types
#   - Create: when a smart contract is deployed
#   - Call: money or message are transferred through different Ethereum address
#   - Suicide: smart contract deletes its code
#   - Reward: miners get the Ether

# %% [markdown]
# **Trace index**
# ```
# A
#   CALLs B
#     CALLs G
#   CALLs C
#     CALLs G
# ```
# then it should look something like:
# ```
# [ {A: []}, {B: [0]}, {G: [0, 0]}, {C: [1]}, {G: [1, 0]} ]
# ```

# %% [markdown]
# [Trace reference](https://medium.com/google-cloud/how-to-query-balances-for-all-ethereum-addresses-in-bigquery-fb594e4034a7)

# %% [markdown]
# **Internal Transaction**
# - If someone asks a smart. contract t osend 10 Ehters to another one,
#   - the Ether transaction from the contract will not be observed in the block -> Internal transaction

# %% [markdown]
# ### Transferring Ethereum

# %%
# %%bigquery trace_df
# select *
# from `bigquery-public-data.crypto_ethereum.traces`
# where DATE(block_timestamp) = "2020-06-07"
# and transaction_hash = '0xc7fd515ec6c10802baccc8de6e93fb24baf5d3c0e033728b161293e842ace70e'
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 619.18query/s]
# Downloading: 100%|██████████| 1/1 [00:03<00:00,  3.64s/rows]

# %%
trace_df
# Out:
#                                     transaction_hash  transaction_index  \
# 0  0xc7fd515ec6c10802baccc8de6e93fb24baf5d3c0e033...                 86
#
#                                  from_address  \
# 0  0x97122ddca38c29b7653d52b07998d06a7128fa0b
#
#                                    to_address                         value  \
# 0  0xb34a4271906780955f437bb982f1f39685ac7940  875100000000000000.000000000
#
#   input output trace_type call_type reward_type    gas  gas_used  subtraces  \
# 0    0x     0x       call      call        None  79000         0          0
#
#   trace_address error  status           block_timestamp  block_number  \
# 0          None  None       1 2020-06-07 09:42:18+00:00      10217910
#
#                                           block_hash  \
# 0  0x5676b7a68ea460696352712d90fbc847e72dda3f387f...
#
#                                             trace_id
# 0  call_0xc7fd515ec6c10802baccc8de6e93fb24baf5d3c...

# %%
trace_df.iloc[0]
# Out:
# transaction_hash     0xc7fd515ec6c10802baccc8de6e93fb24baf5d3c0e033...
# transaction_index                                                   86
# from_address                0x97122ddca38c29b7653d52b07998d06a7128fa0b
# to_address                  0xb34a4271906780955f437bb982f1f39685ac7940
# value                                     875100000000000000.000000000
# input                                                               0x
# output                                                              0x
# trace_type                                                        call
# call_type                                                         call
# reward_type                                                       None
# gas                                                              79000
# gas_used                                                             0
# subtraces                                                            0
# trace_address                                                     None
# error                                                             None
# status                                                               1
# block_timestamp                              2020-06-07 09:42:18+00:00
# block_number                                                  10217910
# block_hash           0x5676b7a68ea460696352712d90fbc847e72dda3f387f...
# trace_id             call_0xc7fd515ec6c10802baccc8de6e93fb24baf5d3c...
# Name: 0, dtype: object

# %%
# %%bigquery transfer_df
# select *
# from `bigquery-public-data.crypto_ethereum.token_transfers`
# where DATE(block_timestamp) = "2020-06-07"
# and transaction_hash = '0xc7fd515ec6c10802baccc8de6e93fb24baf5d3c0e033728b161293e842ace70e'
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 410.52query/s]
# Downloading: 0rows [00:01, ?rows/s]

# %%
transfer_df
# Out:
# Empty DataFrame
# Columns: [token_address, from_address, to_address, value, transaction_hash, log_index, block_timestamp, block_number, block_hash]
# Index: []

# %%
# %%bigquery transaction_df
# select *
# from `bigquery-public-data.crypto_ethereum.transactions`
# where DATE(block_timestamp) = "2020-06-07"
# and (
#     (from_address = '0xb34a4271906780955f437bb982f1f39685ac7940') or
#     (to_address = '0xb34a4271906780955f437bb982f1f39685ac7940')
#     )
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 327.02query/s]
# Downloading: 100%|██████████| 1/1 [00:03<00:00,  3.51s/rows]

# %%
transaction_df
# Out:
#                                                 hash   nonce  \
# 0  0xc7fd515ec6c10802baccc8de6e93fb24baf5d3c0e033...  114541
#
#    transaction_index                                from_address  \
# 0                 86  0x97122ddca38c29b7653d52b07998d06a7128fa0b
#
#                                    to_address                         value  \
# 0  0xb34a4271906780955f437bb982f1f39685ac7940  875100000000000000.000000000
#
#       gas    gas_price input  receipt_cumulative_gas_used  receipt_gas_used  \
# 0  100000  51000000000    0x                      3438927             21000
#
#   receipt_contract_address receipt_root  receipt_status  \
# 0                     None         None               1
#
#             block_timestamp  block_number  \
# 0 2020-06-07 09:42:18+00:00      10217910
#
#                                           block_hash
# 0  0x5676b7a68ea460696352712d90fbc847e72dda3f387f...

# %%
transaction_df.iloc[0]
# Out:
# hash                           0xc7fd515ec6c10802baccc8de6e93fb24baf5d3c0e033...
# nonce                                                                     114541
# transaction_index                                                             86
# from_address                          0x97122ddca38c29b7653d52b07998d06a7128fa0b
# to_address                            0xb34a4271906780955f437bb982f1f39685ac7940
# value                                               875100000000000000.000000000
# gas                                                                       100000
# gas_price                                                            51000000000
# input                                                                         0x
# receipt_cumulative_gas_used                                              3438927
# receipt_gas_used                                                           21000
# receipt_contract_address                                                    None
# receipt_root                                                                None
# receipt_status                                                                 1
# block_timestamp                                        2020-06-07 09:42:18+00:00
# block_number                                                            10217910
# block_hash                     0x5676b7a68ea460696352712d90fbc847e72dda3f387f...
# Name: 0, dtype: object

# %% [markdown]
# - 왜 transfer가 없지? ethereum은 기록 안되는 것?

# %% [markdown]
# ### Buying Axs

# %%
# %%bigquery trace_df
# select *
# from `bigquery-public-data.crypto_ethereum.traces`
# where DATE(block_timestamp) = "2020-06-14"
# and transaction_hash in (
#     '0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39b76d66d93f0f81267eb8',
#     '0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a77a44f66d6f067a3d9488',
#     '0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df788909a34e6973800422d'
# )
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 378.82query/s]
# Downloading: 100%|██████████| 37/37 [00:03<00:00,  9.30rows/s]

# %%
address_dic = {
    '0x7be8076f4ea4a4ad08075c2508e481d6c946d12b':'OpenSea', 
    '0x5b3256965e7C3cF26E11FCAf296DfC8807C01073':'OpenSea: Wallet'
    '0xb34a4271906780955f437bb982f1f39685ac7940':'Nuree_metamask',
    '0xa5409ec958c83c3f309868babaca7c86dcb077c1':'Axs contract'
}
trace_df.from_address = trace_df.from_address.replace(address_dic)
trace_df.to_address = trace_df.to_address.replace(address_dic)

# %%
for t_hash, group in trace_df.groupby('transaction_hash'):
    display(group)
# Out:
#                                      transaction_hash  transaction_index  \
# 0   0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 4   0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 5   0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 6   0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 7   0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 8   0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 9   0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 11  0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 12  0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 16  0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 19  0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
# 30  0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...                123
#
#                                   from_address  \
# 0                                      opensea
# 4                                      opensea
# 5                                      opensea
# 6   0x7762a5d2a8478bbcc348cd039d93845ea1b142d3
# 7   0x7762a5d2a8478bbcc348cd039d93845ea1b142d3
# 8                               Nuree_metamask
# 9                                      opensea
# 11  0xe8bd438d0383cf4d19641eaa4793eddc6cebeaf1
# 12  0x7762a5d2a8478bbcc348cd039d93845ea1b142d3
# 16                                     opensea
# 19                                     opensea
# 30  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d
#
#                                     to_address                        value  \
# 0                                          Axs                         0E-9
# 4   0x7762a5d2a8478bbcc348cd039d93845ea1b142d3                         0E-9
# 5   0x0d4ddea3849c54e16c85cb4354943dc876e05552  28725000000000000.000000000
# 6   0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d                         0E-9
# 7   0xf9e266af4bca5890e2781812cc6a6e89495a79f2                         0E-9
# 8                                      opensea  30000000000000000.000000000
# 9                                          Axs                         0E-9
# 11  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d                         0E-9
# 12                                         Axs                         0E-9
# 16  0x7762a5d2a8478bbcc348cd039d93845ea1b142d3                         0E-9
# 19  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073   1275000000000000.000000000
# 30  0xe8bd438d0383cf4d19641eaa4793eddc6cebeaf1                         0E-9
#
#                                                 input  \
# 0                                          0x97204d8e
# 4                                          0x5c60da1b
# 5                                                  0x
# 6   0x23b872dd0000000000000000000000000d4ddea3849c...
# 7   0x1b0f7ba9000000000000000000000000f5b0a3efb8e8...
# 8   0xab834bab0000000000000000000000007be8076f4ea4...
# 9   0xc45527910000000000000000000000000d4ddea3849c...
# 11                                         0x5c975abb
# 12  0x69dc9ff30000000000000000000000007be8076f4ea4...
# 16  0x1b0f7ba9000000000000000000000000f5b0a3efb8e8...
# 19                                                 0x
# 30  0xf7ebc39a0000000000000000000000000d4ddea3849c...
#
#                                                output trace_type  \
# 0   0x000000000000000000000000f9e266af4bca5890e278...       call
# 4   0x000000000000000000000000f9e266af4bca5890e278...       call
# 5                                                  0x       call
# 6                                                  0x       call
# 7   0x00000000000000000000000000000000000000000000...       call
# 8                                                  0x       call
# 9   0x0000000000000000000000007762a5d2a8478bbcc348...       call
# 11  0x00000000000000000000000000000000000000000000...       call
# 12  0x00000000000000000000000000000000000000000000...       call
# 16  0x00000000000000000000000000000000000000000000...       call
# 19                                                 0x       call
# 30  0x00000000000000000000000000000000000000000000...       call
#
#        call_type reward_type     gas  gas_used  subtraces trace_address error  \
# 0           call        None  189687      1313          0             1  None
# 4           call        None  186749      1225          0             2  None
# 5           call        None    2300         0          0             4  None
# 6           call        None  131314    106501          1         5,0,1  None
# 7   delegatecall        None  140802    113998          2           5,0  None
# 8           call        None  236019    209776          6          None  None
# 9           call        None  193817      1482          0             0  None
# 11          call        None  115552      1628          0     5,0,1,0,0  None
# 12          call        None  133996      1253          0         5,0,0  None
# 16          call        None  145051    116058          1             5  None
# 19          call        None    2300         0          0             3  None
# 30          call        None  120355      4758          1       5,0,1,0  None
#
#     status           block_timestamp  block_number  \
# 0        1 2020-06-14 15:51:04+00:00      10264786
# 4        1 2020-06-14 15:51:04+00:00      10264786
# 5        1 2020-06-14 15:51:04+00:00      10264786
# 6        1 2020-06-14 15:51:04+00:00      10264786
# 7        1 2020-06-14 15:51:04+00:00      10264786
# 8        1 2020-06-14 15:51:04+00:00      10264786
# 9        1 2020-06-14 15:51:04+00:00      10264786
# 11       1 2020-06-14 15:51:04+00:00      10264786
# 12       1 2020-06-14 15:51:04+00:00      10264786
# 16       1 2020-06-14 15:51:04+00:00      10264786
# 19       1 2020-06-14 15:51:04+00:00      10264786
# 30       1 2020-06-14 15:51:04+00:00      10264786
#
#                                            block_hash  \
# 0   0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 4   0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 5   0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 6   0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 7   0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 8   0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 9   0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 11  0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 12  0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 16  0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 19  0xb719c3229267628edce12c6081f1de94229c4c15ba68...
# 30  0xb719c3229267628edce12c6081f1de94229c4c15ba68...
#
#                                              trace_id
# 0   call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 4   call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 5   call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 6   call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 7   call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 8   call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 9   call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 11  call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 12  call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 16  call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 19  call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
# 30  call_0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c...
#                                      transaction_hash  transaction_index  \
# 1   0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 3   0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 10  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 14  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 17  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 18  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 21  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 22  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 24  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 32  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 33  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 34  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
# 36  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...                117
#
#                                   from_address  \
# 1                                      opensea
# 3                               Nuree_metamask
# 10                                     opensea
# 14                                     opensea
# 17  0x87768b7016c8b1dfdd029bc69acbdec43b924f30
# 18  0x87768b7016c8b1dfdd029bc69acbdec43b924f30
# 21  0x87768b7016c8b1dfdd029bc69acbdec43b924f30
# 22  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d
# 24                                     opensea
# 32                                     opensea
# 33                                     opensea
# 34  0xe8bd438d0383cf4d19641eaa4793eddc6cebeaf1
# 36                                     opensea
#
#                                     to_address                        value  \
# 1   0x7e04bb871bef53e54b46b40e13ceb3a5c54f7b8e  15033855534357201.000000000
# 3                                      opensea  15701198661143478.000000000
# 10  0x87768b7016c8b1dfdd029bc69acbdec43b924f30                         0E-9
# 14                                         Axs                         0E-9
# 17  0xf9e266af4bca5890e2781812cc6a6e89495a79f2                         0E-9
# 18                                         Axs                         0E-9
# 21  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d                         0E-9
# 22  0xe8bd438d0383cf4d19641eaa4793eddc6cebeaf1                         0E-9
# 24  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073    667299070715593.000000000
# 32                                         Axs                         0E-9
# 33  0x87768b7016c8b1dfdd029bc69acbdec43b924f30                         0E-9
# 34  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d                         0E-9
# 36                              Nuree_metamask        44056070684.000000000
#
#                                                 input  \
# 1                                                  0x
# 3   0xab834bab0000000000000000000000007be8076f4ea4...
# 10  0x1b0f7ba9000000000000000000000000f5b0a3efb8e8...
# 14  0xc45527910000000000000000000000007e04bb871bef...
# 17  0x1b0f7ba9000000000000000000000000f5b0a3efb8e8...
# 18  0x69dc9ff30000000000000000000000007be8076f4ea4...
# 21  0x23b872dd0000000000000000000000007e04bb871bef...
# 22  0xf7ebc39a0000000000000000000000007e04bb871bef...
# 24                                                 0x
# 32                                         0x97204d8e
# 33                                         0x5c60da1b
# 34                                         0x5c975abb
# 36                                                 0x
#
#                                                output trace_type  \
# 1                                                  0x       call
# 3                                                  0x       call
# 10  0x00000000000000000000000000000000000000000000...       call
# 14  0x00000000000000000000000087768b7016c8b1dfdd02...       call
# 17  0x00000000000000000000000000000000000000000000...       call
# 18  0x00000000000000000000000000000000000000000000...       call
# 21                                                 0x       call
# 22  0x00000000000000000000000000000000000000000000...       call
# 24                                                 0x       call
# 32  0x000000000000000000000000f9e266af4bca5890e278...       call
# 33  0x000000000000000000000000f9e266af4bca5890e278...       call
# 34  0x00000000000000000000000000000000000000000000...       call
# 36                                                 0x       call
#
#        call_type reward_type     gas  gas_used  subtraces trace_address error  \
# 1           call        None    2300         0          0             4  None
# 3           call        None  244948    217884          7          None  None
# 10          call        None  145859    116058          1             6  None
# 14          call        None  202598      1482          0             0  None
# 17  delegatecall        None  141597    113998          2           6,0  None
# 18          call        None  134778      1253          0         6,0,0  None
# 21          call        None  132097    106501          1         6,0,1  None
# 22          call        None  121126      4758          1       6,0,1,0  None
# 24          call        None    2300         0          0             3  None
# 32          call        None  198467      1313          0             1  None
# 33          call        None  195530      1225          0             2  None
# 34          call        None  116311      1628          0     6,0,1,0,0  None
# 36          call        None    2300         0          0             5  None
#
#     status           block_timestamp  block_number  \
# 1        1 2020-06-14 16:11:29+00:00      10264880
# 3        1 2020-06-14 16:11:29+00:00      10264880
# 10       1 2020-06-14 16:11:29+00:00      10264880
# 14       1 2020-06-14 16:11:29+00:00      10264880
# 17       1 2020-06-14 16:11:29+00:00      10264880
# 18       1 2020-06-14 16:11:29+00:00      10264880
# 21       1 2020-06-14 16:11:29+00:00      10264880
# 22       1 2020-06-14 16:11:29+00:00      10264880
# 24       1 2020-06-14 16:11:29+00:00      10264880
# 32       1 2020-06-14 16:11:29+00:00      10264880
# 33       1 2020-06-14 16:11:29+00:00      10264880
# 34       1 2020-06-14 16:11:29+00:00      10264880
# 36       1 2020-06-14 16:11:29+00:00      10264880
#
#                                            block_hash  \
# 1   0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 3   0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 10  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 14  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 17  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 18  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 21  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 22  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 24  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 32  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 33  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 34  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 36  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
#
#                                              trace_id
# 1   call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 3   call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 10  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 14  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 17  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 18  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 21  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 22  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 24  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 32  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 33  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 34  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
# 36  call_0x57116238d0e7da9ecdfb1ab1c95525e20c525f3...
#                                      transaction_hash  transaction_index  \
# 2   0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 13  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 15  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 20  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 23  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 25  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 26  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 27  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 28  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 29  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 31  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
# 35  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...                 22
#
#                                   from_address  \
# 2                                      opensea
# 13                              Nuree_metamask
# 15                                     opensea
# 20  0x7762a5d2a8478bbcc348cd039d93845ea1b142d3
# 23                                     opensea
# 25                                     opensea
# 26  0x7762a5d2a8478bbcc348cd039d93845ea1b142d3
# 27  0xe8bd438d0383cf4d19641eaa4793eddc6cebeaf1
# 28  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d
# 29                                     opensea
# 31                                     opensea
# 35  0x7762a5d2a8478bbcc348cd039d93845ea1b142d3
#
#                                     to_address                        value  \
# 2   0x7762a5d2a8478bbcc348cd039d93845ea1b142d3                         0E-9
# 13                                     opensea  30000000000000000.000000000
# 15  0x7762a5d2a8478bbcc348cd039d93845ea1b142d3                         0E-9
# 20  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d                         0E-9
# 23  0x5b3256965e7c3cf26e11fcaf296dfc8807c01073   1275000000000000.000000000
# 25  0x0d4ddea3849c54e16c85cb4354943dc876e05552  28725000000000000.000000000
# 26  0xf9e266af4bca5890e2781812cc6a6e89495a79f2                         0E-9
# 27  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d                         0E-9
# 28  0xe8bd438d0383cf4d19641eaa4793eddc6cebeaf1                         0E-9
# 29                                         Axs                         0E-9
# 31                                         Axs                         0E-9
# 35                                         Axs                         0E-9
#
#                                                 input  \
# 2   0x1b0f7ba9000000000000000000000000f5b0a3efb8e8...
# 13  0xab834bab0000000000000000000000007be8076f4ea4...
# 15                                         0x5c60da1b
# 20  0x23b872dd0000000000000000000000000d4ddea3849c...
# 23                                                 0x
# 25                                                 0x
# 26  0x1b0f7ba9000000000000000000000000f5b0a3efb8e8...
# 27                                         0x5c975abb
# 28  0xf7ebc39a0000000000000000000000000d4ddea3849c...
# 29                                         0x97204d8e
# 31  0xc45527910000000000000000000000000d4ddea3849c...
# 35  0x69dc9ff30000000000000000000000007be8076f4ea4...
#
#                                                output trace_type  \
# 2   0x00000000000000000000000000000000000000000000...       call
# 13                                                 0x       call
# 15  0x000000000000000000000000f9e266af4bca5890e278...       call
# 20                                                 0x       call
# 23                                                 0x       call
# 25                                                 0x       call
# 26  0x00000000000000000000000000000000000000000000...       call
# 27  0x00000000000000000000000000000000000000000000...       call
# 28  0x00000000000000000000000000000000000000000000...       call
# 29  0x000000000000000000000000f9e266af4bca5890e278...       call
# 31  0x0000000000000000000000007762a5d2a8478bbcc348...       call
# 35  0x00000000000000000000000000000000000000000000...       call
#
#        call_type reward_type     gas  gas_used  subtraces trace_address error  \
# 2           call        None  145051    116058          1             5  None
# 13          call        None  236019    209776          6          None  None
# 15          call        None  186749      1225          0             2  None
# 20          call        None  131314    106501          1         5,0,1  None
# 23          call        None    2300         0          0             3  None
# 25          call        None    2300         0          0             4  None
# 26  delegatecall        None  140802    113998          2           5,0  None
# 27          call        None  115552      1628          0     5,0,1,0,0  None
# 28          call        None  120355      4758          1       5,0,1,0  None
# 29          call        None  189687      1313          0             1  None
# 31          call        None  193817      1482          0             0  None
# 35          call        None  133996      1253          0         5,0,0  None
#
#     status           block_timestamp  block_number  \
# 2        1 2020-06-14 16:11:29+00:00      10264880
# 13       1 2020-06-14 16:11:29+00:00      10264880
# 15       1 2020-06-14 16:11:29+00:00      10264880
# 20       1 2020-06-14 16:11:29+00:00      10264880
# 23       1 2020-06-14 16:11:29+00:00      10264880
# 25       1 2020-06-14 16:11:29+00:00      10264880
# 26       1 2020-06-14 16:11:29+00:00      10264880
# 27       1 2020-06-14 16:11:29+00:00      10264880
# 28       1 2020-06-14 16:11:29+00:00      10264880
# 29       1 2020-06-14 16:11:29+00:00      10264880
# 31       1 2020-06-14 16:11:29+00:00      10264880
# 35       1 2020-06-14 16:11:29+00:00      10264880
#
#                                            block_hash  \
# 2   0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 13  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 15  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 20  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 23  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 25  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 26  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 27  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 28  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 29  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 31  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 35  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
#
#                                              trace_id
# 2   call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 13  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 15  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 20  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 23  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 25  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 26  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 27  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 28  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 29  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 31  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...
# 35  call_0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b...

# %%
# %%bigquery transfer_df
# select *
# from `bigquery-public-data.crypto_ethereum.token_transfers`
# where DATE(block_timestamp) = "2020-06-14"
# and transaction_hash in (
#     '0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39b76d66d93f0f81267eb8',
#     '0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a77a44f66d6f067a3d9488',
#     '0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df788909a34e6973800422d'
# )
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 276.47query/s]
# Downloading: 100%|██████████| 3/3 [00:03<00:00,  1.17s/rows]

# %%
transfer_df
# Out:
#                                 token_address  \
# 0  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d
# 1  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d
# 2  0xf5b0a3efb8e8e4c201e2a935f110eaaf3ffecb8d
#
#                                  from_address  \
# 0  0x0d4ddea3849c54e16c85cb4354943dc876e05552
# 1  0x7e04bb871bef53e54b46b40e13ceb3a5c54f7b8e
# 2  0x0d4ddea3849c54e16c85cb4354943dc876e05552
#
#                                    to_address   value  \
# 0  0xb34a4271906780955f437bb982f1f39685ac7940   46432
# 1  0xb34a4271906780955f437bb982f1f39685ac7940  143766
# 2  0xb34a4271906780955f437bb982f1f39685ac7940   50221
#
#                                     transaction_hash  log_index  \
# 0  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...         16
# 1  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...         96
# 2  0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...        101
#
#             block_timestamp  block_number  \
# 0 2020-06-14 16:11:29+00:00      10264880
# 1 2020-06-14 16:11:29+00:00      10264880
# 2 2020-06-14 15:51:04+00:00      10264786
#
#                                           block_hash
# 0  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 1  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 2  0xb719c3229267628edce12c6081f1de94229c4c15ba68...

# %%
# %%bigquery transaction_df
# select *
# from `bigquery-public-data.crypto_ethereum.transactions`
# where DATE(block_timestamp) = "2020-06-14"
# and `hash` in (
#     '0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39b76d66d93f0f81267eb8',
#     '0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a77a44f66d6f067a3d9488',
#     '0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df788909a34e6973800422d'
# )
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 382.55query/s]
# Downloading: 100%|██████████| 3/3 [00:03<00:00,  1.16s/rows]

# %%
transaction_df
# Out:
#                                                 hash  nonce  \
# 0  0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a7...      1
# 1  0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df7...      2
# 2  0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39...      0
#
#    transaction_index                                from_address  \
# 0                 22  0xb34a4271906780955f437bb982f1f39685ac7940
# 1                117  0xb34a4271906780955f437bb982f1f39685ac7940
# 2                123  0xb34a4271906780955f437bb982f1f39685ac7940
#
#                                    to_address                        value  \
# 0  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  30000000000000000.000000000
# 1  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  15701198661143478.000000000
# 2  0x7be8076f4ea4a4ad08075c2508e481d6c946d12b  30000000000000000.000000000
#
#       gas    gas_price                                              input  \
# 0  272815  27000000000  0xab834bab0000000000000000000000007be8076f4ea4...
# 1  281852  26000000000  0xab834bab0000000000000000000000007be8076f4ea4...
# 2  272815  26000000000  0xab834bab0000000000000000000000007be8076f4ea4...
#
#    receipt_cumulative_gas_used  receipt_gas_used receipt_contract_address  \
# 0                      1562794            212372                     None
# 1                      6938327            220588                     None
# 2                      6276642            212372                     None
#
#   receipt_root  receipt_status           block_timestamp  block_number  \
# 0         None               1 2020-06-14 16:11:29+00:00      10264880
# 1         None               1 2020-06-14 16:11:29+00:00      10264880
# 2         None               1 2020-06-14 15:51:04+00:00      10264786
#
#                                           block_hash
# 0  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 1  0x21fcd95b7386e21ae8f2ae82e896afc4922d2c52b9d0...
# 2  0xb719c3229267628edce12c6081f1de94229c4c15ba68...

# %%
trace_df.groupby('transaction_hash').gas.sum()
# Out:
# transaction_hash
# 0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39b76d66d93f0f81267eb8    1597942
# 0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df788909a34e6973800422d    1640211
# 0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a77a44f66d6f067a3d9488    1597942
# Name: gas, dtype: int64

# %%
trace_df.groupby('transaction_hash').gas_used.sum()
# Out:
# transaction_hash
# 0x37443e2cb01a1ef74ac1e1ed4ac78cdb3ab718c06f39b76d66d93f0f81267eb8    557992
# 0x57116238d0e7da9ecdfb1ab1c95525e20c525f3a0df788909a34e6973800422d    566100
# 0xc6a5a87e0b7f1e72129f75e899f79fee7100b6b023a77a44f66d6f067a3d9488    557992
# Name: gas_used, dtype: int64

# %% [markdown]
# - 왜케 trace가 복잡하지
# - 가스는 어떻게 계산된 거지
# - transfer에는 ethereum말고 다른 것들이 기록되는 건가?
# - anomic match ... 는 뭐지 뒤에 짤린 건 뭘까

# %% [markdown]
# ### 아바타 구매

# %%
# %%bigquery trace_df
# select *
# from `bigquery-public-data.crypto_ethereum.traces`
# where DATE(block_timestamp) = "2020-06-21"
# and transaction_hash = '0x4212c1d67a5d297bf25ee7100234f5056fc25777db427b466e2f76de6cc86314'
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 332.22query/s]
# Downloading: 100%|██████████| 1/1 [00:03<00:00,  3.70s/rows]

# %%
trace_df
# Out:
#                                     transaction_hash  transaction_index  \
# 0  0x4212c1d67a5d297bf25ee7100234f5056fc25777db42...                103
#
#                                  from_address  \
# 0  0xb34a4271906780955f437bb982f1f39685ac7940
#
#                                    to_address                         value  \
# 0  0xe31763aad9294f073ddf18b36503ed037ae5e737  420000000000000000.000000000
#
#         input output trace_type call_type reward_type    gas  gas_used  \
# 0  0xd0e30db0     0x       call      call        None  55970     30292
#
#    subtraces trace_address error  status           block_timestamp  \
# 0          0          None  None       1 2020-06-21 05:29:11+00:00
#
#    block_number                                         block_hash  \
# 0      10307239  0x998dfa328349819ad3c124ba9a775497b05753ff7869...
#
#                                             trace_id
# 0  call_0x4212c1d67a5d297bf25ee7100234f5056fc2577...

# %%
# %%bigquery transfer_df
# select *
# from `bigquery-public-data.crypto_ethereum.token_transfers`
# where DATE(block_timestamp) = "2020-06-21"
# and transaction_hash = '0x4212c1d67a5d297bf25ee7100234f5056fc25777db427b466e2f76de6cc86314'
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 271.88query/s]
# Downloading: 0rows [00:02, ?rows/s]

# %%
transfer_df
# Out:
# Empty DataFrame
# Columns: [token_address, from_address, to_address, value, transaction_hash, log_index, block_timestamp, block_number, block_hash]
# Index: []

# %%
# %%bigquery transaction_df
# select *
# from `bigquery-public-data.crypto_ethereum.transactions`
# where DATE(block_timestamp) = "2020-06-21"
# and `hash` = '0x4212c1d67a5d297bf25ee7100234f5056fc25777db427b466e2f76de6cc86314'
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 361.39query/s]
# Downloading: 100%|██████████| 1/1 [00:03<00:00,  3.61s/rows]

# %%
transaction_df
# Out:
#                                                 hash  nonce  \
# 0  0x4212c1d67a5d297bf25ee7100234f5056fc25777db42...      3
#
#    transaction_index                                from_address  \
# 0                103  0xb34a4271906780955f437bb982f1f39685ac7940
#
#                                    to_address                         value  \
# 0  0xe31763aad9294f073ddf18b36503ed037ae5e737  420000000000000000.000000000
#
#      gas    gas_price       input  receipt_cumulative_gas_used  \
# 0  77034  19000000000  0xd0e30db0                      4915824
#
#    receipt_gas_used receipt_contract_address receipt_root  receipt_status  \
# 0             51356                     None         None               1
#
#             block_timestamp  block_number  \
# 0 2020-06-21 05:29:11+00:00      10307239
#
#                                           block_hash
# 0  0x998dfa328349819ad3c124ba9a775497b05753ff7869...

# %% [markdown]
# - etherscan은 어떻게 deposit이라고 해석했지?
# - 왜 token transfer는 없지?
# - transaction fee는 여기서 어떻게 파싱하지?
# - 7329와 7330은 왜 기록 안됐지
# - 일반적으로 이렇게 구매한 스마트 컨트랙트를 어떻게 구분하지
#   -> ML: node clustering?
#   -> data parsing?

# %% [markdown]
# ### 아바타 매물로 내놓기 (Registry)

# %%
# %%bigquery trace_df
# select *
# from `bigquery-public-data.crypto_ethereum.traces`
# where DATE(block_timestamp) = "2020-06-21"
# and transaction_hash = '0xc0d7f363c2b42e0044dc7568003f5102993ffa71ec4aeb15229965a391e991a9'
# Out:
# Query complete after 0.01s: 100%|██████████| 1/1 [00:00<00:00, 278.93query/s]
# Downloading: 100%|██████████| 3/3 [00:02<00:00,  1.02rows/s]

# %%
trace_df
# Out:
#                                     transaction_hash  transaction_index  \
# 0  0xc0d7f363c2b42e0044dc7568003f5102993ffa71ec4a...                 91
# 1  0xc0d7f363c2b42e0044dc7568003f5102993ffa71ec4a...                 91
# 2  0xc0d7f363c2b42e0044dc7568003f5102993ffa71ec4a...                 91
#
#                                  from_address  \
# 0  0xa5409ec958c83c3f309868babaca7c86dcb077c1
# 1  0xb34a4271906780955f437bb982f1f39685ac7940
# 2  0x506ae7f09042f4bd73f2494d6b1feec364b80efe
#
#                                    to_address value  \
# 0  0x506ae7f09042f4bd73f2494d6b1feec364b80efe  0E-9
# 1  0xa5409ec958c83c3f309868babaca7c86dcb077c1  0E-9
# 2  0xf9e266af4bca5890e2781812cc6a6e89495a79f2  0E-9
#
#                                                input  \
# 0  0x608060405234801561001057600080fd5b5060405161...
# 1                                         0xddd81f82
# 2  0x485cc955000000000000000000000000b34a42719067...
#
#                                               output trace_type     call_type  \
# 0  0x6080604052600436106100825763ffffffff7c010000...     create          None
# 1  0x000000000000000000000000506ae7f09042f4bd73f2...       call          call
# 2                                                 0x       call  delegatecall
#
#   reward_type     gas  gas_used  subtraces trace_address error  status  \
# 0        None  368036    313583          1             0  None       1
# 1        None  409479    370338          1          None  None       1
# 2        None  317467     44620          0           0,0  None       1
#
#             block_timestamp  block_number  \
# 0 2020-06-21 14:21:31+00:00      10309617
# 1 2020-06-21 14:21:31+00:00      10309617
# 2 2020-06-21 14:21:31+00:00      10309617
#
#                                           block_hash  \
# 0  0x6b718e3c47100de2d2b44a567674ba950e14a75d0d19...
# 1  0x6b718e3c47100de2d2b44a567674ba950e14a75d0d19...
# 2  0x6b718e3c47100de2d2b44a567674ba950e14a75d0d19...
#
#                                             trace_id
# 0  create_0xc0d7f363c2b42e0044dc7568003f5102993ff...
# 1  call_0xc0d7f363c2b42e0044dc7568003f5102993ffa7...
# 2  call_0xc0d7f363c2b42e0044dc7568003f5102993ffa7...

# %%
# %%bigquery transfer_df
# select *
# from `bigquery-public-data.crypto_ethereum.token_transfers`
# where DATE(block_timestamp) = "2020-06-21"
# and transaction_hash = '0xc0d7f363c2b42e0044dc7568003f5102993ffa71ec4aeb15229965a391e991a9'
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 373.56query/s]
# Downloading: 0rows [00:01, ?rows/s]

# %%
transfer_df
# Out:
# Empty DataFrame
# Columns: [token_address, from_address, to_address, value, transaction_hash, log_index, block_timestamp, block_number, block_hash]
# Index: []

# %%
# %%bigquery transaction_df
# select *
# from `bigquery-public-data.crypto_ethereum.transactions`
# where DATE(block_timestamp) = "2020-06-21"
# and `hash` = '0xc0d7f363c2b42e0044dc7568003f5102993ffa71ec4aeb15229965a391e991a9'
# Out:
# Query complete after 0.00s: 100%|██████████| 1/1 [00:00<00:00, 277.38query/s]
# Downloading: 100%|██████████| 1/1 [00:03<00:00,  3.61s/rows]

# %%
transaction_df
# Out:
#                                                 hash  nonce  \
# 0  0xc0d7f363c2b42e0044dc7568003f5102993ffa71ec4a...      4
#
#    transaction_index                                from_address  \
# 0                 91  0xb34a4271906780955f437bb982f1f39685ac7940
#
#                                    to_address value     gas    gas_price  \
# 0  0xa5409ec958c83c3f309868babaca7c86dcb077c1  0E-9  430543  36000000000
#
#         input  receipt_cumulative_gas_used  receipt_gas_used  \
# 0  0xddd81f82                      4222204            391402
#
#   receipt_contract_address receipt_root  receipt_status  \
# 0                     None         None               1
#
#             block_timestamp  block_number  \
# 0 2020-06-21 14:21:31+00:00      10309617
#
#                                           block_hash
# 0  0x6b718e3c47100de2d2b44a567674ba950e14a75d0d19...

# %%
0xfae0a1e620342d83b200389adb0689eac04eb2d0f4d78aaeb6d15905375e4b35

# %% [markdown]
# ## Next to do

# %% [markdown]
# - Balance table
#   - daily로 각 address의 잔고 보여줌
#   - 잔고 많은 주요 유저들 탐색 가능
